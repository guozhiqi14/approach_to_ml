# %%
# entity_embeddings.py
import os
import gc
import joblib
import copy
import pandas as pd
import numpy as np
from sklearn import metrics, preprocessing
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import callbacks
from tensorflow.keras import backend as K
from tensorflow.keras import utils

# %%
df = pd.read_csv("../input/adult_folds.csv")

# %%
df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       59           Private  184493  Some-college               10
# 1       62           Private   81116  Some-college               10
# 2       74           Private  101590   Prof-school               15
# 3       36                 ?  187167       HS-grad                9
# 4       51       Federal-gov   27166       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 48837   27           Private  250314           9th                5
# 48838   39  Self-emp-not-inc  327120       HS-grad                9
# 48839   67           Private  219687  Some-college               10
# 48840   50           Private  330543     Preschool                1
# 48841   32           Private   49539  Some-college               10
#
#            marital-status       occupation   relationship   race  gender  \
# 0      Married-civ-spouse            Sales        Husband  White    Male
# 1                Divorced     Adm-clerical  Not-in-family  White    Male
# 2                 Widowed     Adm-clerical  Not-in-family  Black  Female
# 3               Separated                ?  Not-in-family  White  Female
# 4      Married-civ-spouse     Tech-support        Husband  White    Male
# ...                   ...              ...            ...    ...     ...
# 48837  Married-civ-spouse  Protective-serv        Husband  White    Male
# 48838  Married-civ-spouse     Craft-repair        Husband  White    Male
# 48839             Widowed            Sales  Not-in-family  White    Male
# 48840  Married-civ-spouse    Other-service        Husband  White    Male
# 48841       Never-married    Other-service  Not-in-family  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income  kfold
# 0                 0             0              40  United-States   >50K      0
# 1                 0          1974              40  United-States  <=50K      0
# 2                 0             0              20  United-States  <=50K      0
# 3                 0             0              30  United-States  <=50K      0
# 4                 0             0              40  United-States  <=50K      0
# ...             ...           ...             ...            ...    ...    ...
# 48837             0             0              40      Guatemala  <=50K      4
# 48838             0             0              40       Portugal  <=50K      4
# 48839             0             0              18  United-States  <=50K      4
# 48840             0             0              40         Mexico  <=50K      4
# 48841          3674             0              40  United-States  <=50K      4
#
# [48842 rows x 16 columns]

# %%
# all columns are features except id, target and kfold columns
features = [
    f for f in df.columns if f not in ("id", "income", "kfold")
]

# %%
features
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'educational-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'gender',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %%
# map targets to 0s and 1s
target_mapping = {"<=50K": 0,
                  ">50K": 1}

df.loc[:, "income"] = df.income.map(target_mapping)

# %%
# fill all NaN values with NONE
# note that I am converting all columns to "strings" # it doesnt matter because all are categories
for col in features:
    df.loc[:, col] = df[col].astype(str).fillna("NONE")

# %%
df
# Out:
#       age         workclass  fnlwgt     education educational-num  \
# 0      59           Private  184493  Some-college              10
# 1      62           Private   81116  Some-college              10
# 2      74           Private  101590   Prof-school              15
# 3      36                 ?  187167       HS-grad               9
# 4      51       Federal-gov   27166       HS-grad               9
# ...    ..               ...     ...           ...             ...
# 48837  27           Private  250314           9th               5
# 48838  39  Self-emp-not-inc  327120       HS-grad               9
# 48839  67           Private  219687  Some-college              10
# 48840  50           Private  330543     Preschool               1
# 48841  32           Private   49539  Some-college              10
#
#            marital-status       occupation   relationship   race  gender  \
# 0      Married-civ-spouse            Sales        Husband  White    Male
# 1                Divorced     Adm-clerical  Not-in-family  White    Male
# 2                 Widowed     Adm-clerical  Not-in-family  Black  Female
# 3               Separated                ?  Not-in-family  White  Female
# 4      Married-civ-spouse     Tech-support        Husband  White    Male
# ...                   ...              ...            ...    ...     ...
# 48837  Married-civ-spouse  Protective-serv        Husband  White    Male
# 48838  Married-civ-spouse     Craft-repair        Husband  White    Male
# 48839             Widowed            Sales  Not-in-family  White    Male
# 48840  Married-civ-spouse    Other-service        Husband  White    Male
# 48841       Never-married    Other-service  Not-in-family  White  Female
#
#       capital-gain capital-loss hours-per-week native-country  income  kfold
# 0                0            0             40  United-States       1      0
# 1                0         1974             40  United-States       0      0
# 2                0            0             20  United-States       0      0
# 3                0            0             30  United-States       0      0
# 4                0            0             40  United-States       0      0
# ...            ...          ...            ...            ...     ...    ...
# 48837            0            0             40      Guatemala       0      4
# 48838            0            0             40       Portugal       0      4
# 48839            0            0             18  United-States       0      4
# 48840            0            0             40         Mexico       0      4
# 48841         3674            0             40  United-States       0      4
#
# [48842 rows x 16 columns]

# %%
# encode all features with label encoder individually
# in a live setting you need to save all label encoders
for feat in features:
    lbl_enc = preprocessing.LabelEncoder()
    df.loc[:, feat] = lbl_enc.fit_transform(df[feat].values)

# %%
# get training data using folds
df_train = df[df.kfold != 0].reset_index(drop=True)

# get validation data using folds
df_valid = df[df.kfold == 0].reset_index(drop=True)

# %%
df_train
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0       17          2   15013          7                3               2
# 1       37          2    3895         11               15               2
# 2       35          1   13921          9                4               2
# 3       29          4   13119          9                4               2
# 4       24          4   21571          9                4               0
# ...    ...        ...     ...        ...              ...             ...
# 39068   10          4   16299          6               11               2
# 39069   22          6   20702         11               15               2
# 39070   50          4   13749         15                1               6
# 39071   33          4   20856         13                0               2
# 39072   15          4   24919         15                1               4
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0              10             0     4       1             0             0
# 1               3             0     4       1             0             0
# 2              11             0     4       1             0             0
# 3              10             0     4       1             0             0
# 4               4             1     4       1             0             0
# ...           ...           ...   ...     ...           ...           ...
# 39068          11             0     4       1             0             0
# 39069           3             0     4       1             0             0
# 39070          12             1     4       1             0             0
# 39071           8             0     4       1             0             0
# 39072           8             1     4       0            75             0
#
#        hours-per-week  native-country  income  kfold
# 0                  34              39       1      1
# 1                  34              39       1      1
# 2                  39              39       1      1
# 3                  34               0       1      1
# 4                  45              39       1      1
# ...               ...             ...     ...    ...
# 39068              34              13       0      4
# 39069              34              32       0      4
# 39070               9              39       0      4
# 39071              34              26       0      4
# 39072              34              39       0      4
#
# [39073 rows x 16 columns]

# %%
# init list of inputs for embeddings
inputs = []
# init list of outputs for embeddings
outputs = []

# %%
catcols
# Out:
# ['workclass']

# %%
catcols = [features[1]]

# loop over all categorical columns
for c in features:
    # find the number of df values in the column
    num_unique_values = int(df[c].nunique())
    print('num_unique_values:',num_unique_values)
    # simple dimension of embedding calculator
    # min size is half of the number of unique values
    # max size is 50. max size depends on the number of unique
    # categories too. 50 is quite sufficient most of the times
    # but if you have millions of unique values, you might need
    # a larger dimension
    embed_dim = int(min(np.ceil((num_unique_values)/2), 50))
    print('embed_dim:',embed_dim)

    # simple keras input layer with size 1
    inp = layers.Input(shape=(1,))

    # add embedding layer to raw input
    # embedding size is always 1 more than unique values in input
    out = layers.Embedding(
    num_unique_values + 1, embed_dim, name=c)(inp)


    # 1-d spatial dropout is the standard for emebedding layers
    # you can use it in NLP tasks too
    out = layers.SpatialDropout1D(0.3)(out)

    # reshape the input to the dimension of embedding
    # this becomes our output layer for current feature
    out = layers.Reshape(target_shape=(embed_dim, ))(out)

    # add input to input list
    inputs.append(inp)

    # add output to output list
    outputs.append(out)
# Out:
# num_unique_values: 74
# embed_dim: 37
# num_unique_values: 9
# embed_dim: 5
# num_unique_values: 28523
# embed_dim: 50
# num_unique_values: 16
# embed_dim: 8
# num_unique_values: 16
# embed_dim: 8
# num_unique_values: 7
# embed_dim: 4
# num_unique_values: 15
# embed_dim: 8
# num_unique_values: 6
# embed_dim: 3
# num_unique_values: 5
# embed_dim: 3
# num_unique_values: 2
# embed_dim: 1
# num_unique_values: 123
# embed_dim: 50
# num_unique_values: 99
# embed_dim: 50
# num_unique_values: 96
# embed_dim: 48
# num_unique_values: 42
# embed_dim: 21

# %%
layers.Input(shape=(1,))
# Out:
# <tf.Tensor 'input_51:0' shape=(None, 1) dtype=float32>

# %%
layers.Embedding(
    num_unique_values + 1, embed_dim, name=c)(inp)
# Out:
# <tf.Tensor 'native-country_5/Identity:0' shape=(None, 1, 21) dtype=float32>

# %%
inp
# Out:
# <tf.Tensor 'input_50:0' shape=(None, 1) dtype=float32>

# %%
out
# Out:
# <tf.Tensor 'reshape_46/Identity:0' shape=(None, 21) dtype=float32>

# %%
inputs
# Out:
# [<tf.Tensor 'input_37:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_38:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_39:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_40:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_41:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_42:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_43:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_44:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_45:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_46:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_47:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_48:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_49:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'input_50:0' shape=(None, 1) dtype=float32>]

# %%
outputs
# Out:
# [<tf.Tensor 'reshape_33/Identity:0' shape=(None, 37) dtype=float32>,
#  <tf.Tensor 'reshape_34/Identity:0' shape=(None, 5) dtype=float32>,
#  <tf.Tensor 'reshape_35/Identity:0' shape=(None, 50) dtype=float32>,
#  <tf.Tensor 'reshape_36/Identity:0' shape=(None, 8) dtype=float32>,
#  <tf.Tensor 'reshape_37/Identity:0' shape=(None, 8) dtype=float32>,
#  <tf.Tensor 'reshape_38/Identity:0' shape=(None, 4) dtype=float32>,
#  <tf.Tensor 'reshape_39/Identity:0' shape=(None, 8) dtype=float32>,
#  <tf.Tensor 'reshape_40/Identity:0' shape=(None, 3) dtype=float32>,
#  <tf.Tensor 'reshape_41/Identity:0' shape=(None, 3) dtype=float32>,
#  <tf.Tensor 'reshape_42/Identity:0' shape=(None, 1) dtype=float32>,
#  <tf.Tensor 'reshape_43/Identity:0' shape=(None, 50) dtype=float32>,
#  <tf.Tensor 'reshape_44/Identity:0' shape=(None, 50) dtype=float32>,
#  <tf.Tensor 'reshape_45/Identity:0' shape=(None, 48) dtype=float32>,
#  <tf.Tensor 'reshape_46/Identity:0' shape=(None, 21) dtype=float32>]

# %%
# concatenate all output layers
x = layers.Concatenate()(outputs)

# add a batchnorm layer.
# from here, everything is up to you
# you can try different architectures
# this is the architecture I like to use
# if you have numerical features, you should add # them here or in concatenate layer
x = layers.BatchNormalization()(x)

# %%
x
# Out:
# <tf.Tensor 'batch_normalization_8/Identity:0' shape=(None, 296) dtype=float32>

# %%
x = layers.Dense(300, activation="relu")(x)

# %%
x
# Out:
# <tf.Tensor 'dense_8/Identity:0' shape=(None, 300) dtype=float32>

# %%
x = layers.Dropout(0.5)(x)
x = layers.BatchNormalization()(x)

x = layers.Dense(300, activation="relu")(x)
x = layers.Dropout(0.5)(x)
x = layers.BatchNormalization()(x)

x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.5)(x)
x = layers.BatchNormalization()(x)

# using softmax and treating it as a two class problem
# you can also use sigmoid, then you need to use only one
# output class
y = layers.Dense(2, activation="softmax")(x)

# create final model
model = Model(inputs=inputs, outputs=y)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_37 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_38 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_39 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_40 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_41 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_42 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_43 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_44 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_45 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_46 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_47 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_48 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_49 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_50 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# age (Embedding)                 (None, 1, 37)        2775        input_37[0][0]
# __________________________________________________________________________________________________
# workclass (Embedding)           (None, 1, 5)         50          input_38[0][0]
# __________________________________________________________________________________________________
# fnlwgt (Embedding)              (None, 1, 50)        1426200     input_39[0][0]
# __________________________________________________________________________________________________
# education (Embedding)           (None, 1, 8)         136         input_40[0][0]
# __________________________________________________________________________________________________
# educational-num (Embedding)     (None, 1, 8)         136         input_41[0][0]
# __________________________________________________________________________________________________
# marital-status (Embedding)      (None, 1, 4)         32          input_42[0][0]
# __________________________________________________________________________________________________
# occupation (Embedding)          (None, 1, 8)         128         input_43[0][0]
# __________________________________________________________________________________________________
# relationship (Embedding)        (None, 1, 3)         21          input_44[0][0]
# __________________________________________________________________________________________________
# race (Embedding)                (None, 1, 3)         18          input_45[0][0]
# __________________________________________________________________________________________________
# gender (Embedding)              (None, 1, 1)         3           input_46[0][0]
# __________________________________________________________________________________________________
# capital-gain (Embedding)        (None, 1, 50)        6200        input_47[0][0]
# __________________________________________________________________________________________________
# capital-loss (Embedding)        (None, 1, 50)        5000        input_48[0][0]
# __________________________________________________________________________________________________
# hours-per-week (Embedding)      (None, 1, 48)        4656        input_49[0][0]
# __________________________________________________________________________________________________
# native-country (Embedding)      (None, 1, 21)        903         input_50[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_33 (SpatialDr (None, 1, 37)        0           age[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_34 (SpatialDr (None, 1, 5)         0           workclass[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_35 (SpatialDr (None, 1, 50)        0           fnlwgt[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_36 (SpatialDr (None, 1, 8)         0           education[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_37 (SpatialDr (None, 1, 8)         0           educational-num[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_38 (SpatialDr (None, 1, 4)         0           marital-status[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_39 (SpatialDr (None, 1, 8)         0           occupation[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_40 (SpatialDr (None, 1, 3)         0           relationship[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_41 (SpatialDr (None, 1, 3)         0           race[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_42 (SpatialDr (None, 1, 1)         0           gender[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_43 (SpatialDr (None, 1, 50)        0           capital-gain[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_44 (SpatialDr (None, 1, 50)        0           capital-loss[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_45 (SpatialDr (None, 1, 48)        0           hours-per-week[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_46 (SpatialDr (None, 1, 21)        0           native-country[0][0]
# __________________________________________________________________________________________________
# reshape_33 (Reshape)            (None, 37)           0           spatial_dropout1d_33[0][0]
# __________________________________________________________________________________________________
# reshape_34 (Reshape)            (None, 5)            0           spatial_dropout1d_34[0][0]
# __________________________________________________________________________________________________
# reshape_35 (Reshape)            (None, 50)           0           spatial_dropout1d_35[0][0]
# __________________________________________________________________________________________________
# reshape_36 (Reshape)            (None, 8)            0           spatial_dropout1d_36[0][0]
# __________________________________________________________________________________________________
# reshape_37 (Reshape)            (None, 8)            0           spatial_dropout1d_37[0][0]
# __________________________________________________________________________________________________
# reshape_38 (Reshape)            (None, 4)            0           spatial_dropout1d_38[0][0]
# __________________________________________________________________________________________________
# reshape_39 (Reshape)            (None, 8)            0           spatial_dropout1d_39[0][0]
# __________________________________________________________________________________________________
# reshape_40 (Reshape)            (None, 3)            0           spatial_dropout1d_40[0][0]
# __________________________________________________________________________________________________
# reshape_41 (Reshape)            (None, 3)            0           spatial_dropout1d_41[0][0]
# __________________________________________________________________________________________________
# reshape_42 (Reshape)            (None, 1)            0           spatial_dropout1d_42[0][0]
# __________________________________________________________________________________________________
# reshape_43 (Reshape)            (None, 50)           0           spatial_dropout1d_43[0][0]
# __________________________________________________________________________________________________
# reshape_44 (Reshape)            (None, 50)           0           spatial_dropout1d_44[0][0]
# __________________________________________________________________________________________________
# reshape_45 (Reshape)            (None, 48)           0           spatial_dropout1d_45[0][0]
# __________________________________________________________________________________________________
# reshape_46 (Reshape)            (None, 21)           0           spatial_dropout1d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 296)          0           reshape_33[0][0]
#                                                                  reshape_34[0][0]
#                                                                  reshape_35[0][0]
#                                                                  reshape_36[0][0]
#                                                                  reshape_37[0][0]
#                                                                  reshape_38[0][0]
#                                                                  reshape_39[0][0]
#                                                                  reshape_40[0][0]
#                                                                  reshape_41[0][0]
#                                                                  reshape_42[0][0]
#                                                                  reshape_43[0][0]
#                                                                  reshape_44[0][0]
#                                                                  reshape_45[0][0]
#                                                                  reshape_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 296)          1184        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 300)          89100       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 300)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300)          1200        dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 300)          90300       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 300)          0           dense_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 300)          1200        dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          38528       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128)          512         dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            258         batch_normalization_11[0][0]
# ==================================================================================================
# Total params: 1,668,540
# Trainable params: 1,666,492
# Non-trainable params: 2,048
# __________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
# our features are lists of lists
xtrain = [
    df_train[features].values[:, k] for k in range(len(features))
]
xvalid = [
    df_valid[features].values[:, k] for k in range(len(features))
]

# %%
df_train
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0       17          2   15013          7                3               2
# 1       37          2    3895         11               15               2
# 2       35          1   13921          9                4               2
# 3       29          4   13119          9                4               2
# 4       24          4   21571          9                4               0
# ...    ...        ...     ...        ...              ...             ...
# 39068   10          4   16299          6               11               2
# 39069   22          6   20702         11               15               2
# 39070   50          4   13749         15                1               6
# 39071   33          4   20856         13                0               2
# 39072   15          4   24919         15                1               4
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0              10             0     4       1             0             0
# 1               3             0     4       1             0             0
# 2              11             0     4       1             0             0
# 3              10             0     4       1             0             0
# 4               4             1     4       1             0             0
# ...           ...           ...   ...     ...           ...           ...
# 39068          11             0     4       1             0             0
# 39069           3             0     4       1             0             0
# 39070          12             1     4       1             0             0
# 39071           8             0     4       1             0             0
# 39072           8             1     4       0            75             0
#
#        hours-per-week  native-country  income  kfold
# 0                  34              39       1      1
# 1                  34              39       1      1
# 2                  39              39       1      1
# 3                  34               0       1      1
# 4                  45              39       1      1
# ...               ...             ...     ...    ...
# 39068              34              13       0      4
# 39069              34              32       0      4
# 39070               9              39       0      4
# 39071              34              26       0      4
# 39072              34              39       0      4
#
# [39073 rows x 16 columns]

# %%
xtrain
# Out:
# [array([17, 37, 35, ..., 50, 33, 15]),
#  array([2, 2, 1, ..., 4, 4, 4]),
#  array([15013,  3895, 13921, ..., 13749, 20856, 24919]),
#  array([ 7, 11,  9, ..., 15, 13, 15]),
#  array([ 3, 15,  4, ...,  1,  0,  1]),
#  array([2, 2, 2, ..., 6, 2, 4]),
#  array([10,  3, 11, ..., 12,  8,  8]),
#  array([0, 0, 0, ..., 1, 0, 1]),
#  array([4, 4, 4, ..., 4, 4, 4]),
#  array([1, 1, 1, ..., 1, 1, 0]),
#  array([ 0,  0,  0, ...,  0,  0, 75]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([34, 34, 39, ...,  9, 34, 34]),
#  array([39, 39, 39, ..., 39, 26, 39])]

# %%
ytrain
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
# fetch target columns
ytrain = df_train.income.values
yvalid = df_valid.income.values

# %%
utils.to_categorical(ytrain)
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)

# %%
# # convert target columns to categories
# # this is just binarization
ytrain_cat = utils.to_categorical(ytrain)
yvalid_cat = utils.to_categorical(yvalid)

# %%
# fit the model
model.fit(xtrain, ytrain_cat,
          validation_data=(xvalid, yvalid_cat), verbose=1,
          batch_size=1024,
          epochs=5
          )
# Out:
# Epoch 1/5
# 39/39 [==============================] - 2s 48ms/step - loss: 0.7238 - val_loss: 0.5424
# Epoch 2/5
# 39/39 [==============================] - 1s 38ms/step - loss: 0.4354 - val_loss: 0.5618
# Epoch 3/5
# 39/39 [==============================] - 2s 39ms/step - loss: 0.3384 - val_loss: 0.5536
# Epoch 4/5
# 39/39 [==============================] - 2s 39ms/step - loss: 0.2993 - val_loss: 0.5455
# Epoch 5/5
# 39/39 [==============================] - 2s 46ms/step - loss: 0.2716 - val_loss: 0.5812

# %%
model.predict(xvalid)
# Out:
# array([[0.90105677, 0.09894323],
#        [0.94769645, 0.05230359],
#        [0.93998176, 0.06001817],
#        ...,
#        [0.9074634 , 0.09253663],
#        [0.96751887, 0.03248118],
#        [0.95046455, 0.0495355 ]], dtype=float32)

# %%
valid_preds = model.predict(xvalid)[:, 1]

# print roc auc score
print("AUC is:", metrics.roc_auc_score(yvalid, valid_preds))
# Out:
# AUC is: 0.9150470326432893

# %%
pd.date_range('2020-01-06', '2020-01-10', freq='10H').to_series()
# Out:
# 2020-01-06 00:00:00   2020-01-06 00:00:00
# 2020-01-06 10:00:00   2020-01-06 10:00:00
# 2020-01-06 20:00:00   2020-01-06 20:00:00
# 2020-01-07 06:00:00   2020-01-07 06:00:00
# 2020-01-07 16:00:00   2020-01-07 16:00:00
# 2020-01-08 02:00:00   2020-01-08 02:00:00
# 2020-01-08 12:00:00   2020-01-08 12:00:00
# 2020-01-08 22:00:00   2020-01-08 22:00:00
# 2020-01-09 08:00:00   2020-01-09 08:00:00
# 2020-01-09 18:00:00   2020-01-09 18:00:00
# Freq: 10H, dtype: datetime64[ns]
