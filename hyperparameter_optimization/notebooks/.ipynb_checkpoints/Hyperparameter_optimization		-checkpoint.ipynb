# %%
import numpy as np 
import pandas as pd
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

# %%
# !pwd
# Out:
# /Users/guozhiqi/Desktop/approach_to_any_ml_problem/hyperparameter_optimization/notebooks

# %%
# read the training data
df = pd.read_csv("../input/train.csv")

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
# features are all columns without price_range
# note that there is no id column in this dataset
# here we have training features
X = df.drop("price_range", axis=1).values
# and the targets
y = df.price_range.values

# %%
X
# Out:
# array([[8.420e+02, 0.000e+00, 2.200e+00, ..., 0.000e+00, 0.000e+00,
#         1.000e+00],
#        [1.021e+03, 1.000e+00, 5.000e-01, ..., 1.000e+00, 1.000e+00,
#         0.000e+00],
#        [5.630e+02, 1.000e+00, 5.000e-01, ..., 1.000e+00, 1.000e+00,
#         0.000e+00],
#        ...,
#        [1.911e+03, 0.000e+00, 9.000e-01, ..., 1.000e+00, 1.000e+00,
#         0.000e+00],
#        [1.512e+03, 0.000e+00, 9.000e-01, ..., 1.000e+00, 1.000e+00,
#         1.000e+00],
#        [5.100e+02, 1.000e+00, 2.000e+00, ..., 1.000e+00, 1.000e+00,
#         1.000e+00]])

# %%
y
# Out:
# array([1, 2, 2, ..., 3, 0, 3])

# %%
# define the model here
# i am using random forest with n_jobs=-1
# n_jobs=-1 => use all cores
classifier = ensemble.RandomForestClassifier(n_jobs=-1)

# %%
# define a grid of parameters
# this can be a dictionary or a list of
# dictionaries
param_grid = {
    "n_estimators": [100, 200, 250, 300, 400, 500], "max_depth": [1, 2, 5, 7, 11, 15],
    "criterion": ["gini", "entropy"]
}

# %%
# initialize grid search
# estimator is the model that we have defined
# param_grid is the grid of parameters
# we use accuracy as our metric. you can define your own
# higher value of verbose implies a lot of details are printed
# cv=5 means that we are using 5 fold cv (not stratified)
model = model_selection.GridSearchCV(
    estimator=classifier, param_grid=param_grid, scoring="accuracy", verbose=10,
    n_jobs=1,
    cv=5)

# %%
# fit the model and extract best score
model.fit(X, y)
print(f"Best score: {model.best_score_}")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=gini, max_depth=1, n_estimators=100, score=0.578, total=   1.8s
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=100, score=0.620, total=   0.2s
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=100, score=0.557, total=   0.2s
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.3s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=100, score=0.555, total=   0.3s
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    2.5s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=100, score=0.535, total=   0.3s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.8s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=200, score=0.580, total=   0.3s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    3.1s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=200, score=0.625, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    3.5s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=200, score=0.613, total=   0.3s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    3.8s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=200, score=0.598, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    4.2s remaining:    0.0s
# [CV]  criterion=gini, max_depth=1, n_estimators=200, score=0.575, total=   0.3s
# [CV] criterion=gini, max_depth=1, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=250, score=0.600, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=250, score=0.608, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=250, score=0.575, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=250, score=0.623, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=250, score=0.580, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=300, score=0.608, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=300, score=0.585, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=300, score=0.635, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=300, score=0.562, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=300, score=0.555, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=400, score=0.583, total=   0.5s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=400, score=0.580, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=400, score=0.600, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=400, score=0.585, total=   0.6s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=400, score=0.593, total=   0.5s
# [CV] criterion=gini, max_depth=1, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=500, score=0.613, total=   0.6s
# [CV] criterion=gini, max_depth=1, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=500, score=0.565, total=   0.7s
# [CV] criterion=gini, max_depth=1, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=500, score=0.620, total=   0.6s
# [CV] criterion=gini, max_depth=1, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=500, score=0.613, total=   0.6s
# [CV] criterion=gini, max_depth=1, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=1, n_estimators=500, score=0.580, total=   0.6s
# [CV] criterion=gini, max_depth=2, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=100, score=0.785, total=   0.3s
# [CV] criterion=gini, max_depth=2, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=100, score=0.718, total=   0.2s
# [CV] criterion=gini, max_depth=2, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=100, score=0.792, total=   0.2s
# [CV] criterion=gini, max_depth=2, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=100, score=0.735, total=   0.2s
# [CV] criterion=gini, max_depth=2, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=100, score=0.745, total=   0.2s
# [CV] criterion=gini, max_depth=2, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=200, score=0.752, total=   0.3s
# [CV] criterion=gini, max_depth=2, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=200, score=0.735, total=   0.3s
# [CV] criterion=gini, max_depth=2, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=200, score=0.755, total=   0.3s
# [CV] criterion=gini, max_depth=2, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=200, score=0.775, total=   0.3s
# [CV] criterion=gini, max_depth=2, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=200, score=0.762, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=250, score=0.730, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=250, score=0.775, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=250, score=0.790, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=250, score=0.795, total=   0.5s
# [CV] criterion=gini, max_depth=2, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=250, score=0.725, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=300, score=0.755, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=300, score=0.740, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=300, score=0.752, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=300, score=0.772, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=300, score=0.740, total=   0.4s
# [CV] criterion=gini, max_depth=2, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=400, score=0.792, total=   0.5s
# [CV] criterion=gini, max_depth=2, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=400, score=0.750, total=   0.5s
# [CV] criterion=gini, max_depth=2, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=400, score=0.782, total=   0.5s
# [CV] criterion=gini, max_depth=2, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=400, score=0.790, total=   0.5s
# [CV] criterion=gini, max_depth=2, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=400, score=0.738, total=   0.5s
# [CV] criterion=gini, max_depth=2, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=500, score=0.760, total=   0.6s
# [CV] criterion=gini, max_depth=2, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=500, score=0.740, total=   0.6s
# [CV] criterion=gini, max_depth=2, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=500, score=0.782, total=   0.6s
# [CV] criterion=gini, max_depth=2, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=500, score=0.777, total=   0.6s
# [CV] criterion=gini, max_depth=2, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=2, n_estimators=500, score=0.760, total=   0.6s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=100, score=0.838, total=   0.3s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=100, score=0.833, total=   0.3s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=100, score=0.873, total=   0.2s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=100, score=0.828, total=   0.3s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=100, score=0.807, total=   0.3s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=200, score=0.825, total=   0.3s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=200, score=0.835, total=   0.3s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=200, score=0.870, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=200, score=0.840, total=   0.3s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=200, score=0.828, total=   0.3s
# [CV] criterion=gini, max_depth=5, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=250, score=0.828, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=250, score=0.858, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=250, score=0.855, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=250, score=0.848, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=250, score=0.810, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=300, score=0.848, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=300, score=0.838, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=300, score=0.858, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=300, score=0.830, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=300, score=0.835, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=400, score=0.825, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=400, score=0.855, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=400, score=0.860, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=400, score=0.848, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=400, score=0.825, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=500, score=0.828, total=   0.9s
# [CV] criterion=gini, max_depth=5, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=500, score=0.843, total=   0.8s
# [CV] criterion=gini, max_depth=5, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=500, score=0.868, total=   0.9s
# [CV] criterion=gini, max_depth=5, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=500, score=0.840, total=   1.1s
# [CV] criterion=gini, max_depth=5, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=5, n_estimators=500, score=0.823, total=   1.0s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=100, score=0.848, total=   0.3s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=100, score=0.873, total=   0.3s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=100, score=0.885, total=   0.3s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=100, score=0.868, total=   0.3s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=100, score=0.833, total=   0.3s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=200, score=0.860, total=   0.3s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=200, score=0.870, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=200, score=0.895, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=200, score=0.860, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=200, score=0.850, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=250, score=0.870, total=   0.6s
# [CV] criterion=gini, max_depth=7, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=250, score=0.863, total=   0.5s
# [CV] criterion=gini, max_depth=7, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=250, score=0.890, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=250, score=0.858, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=250 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=250, score=0.838, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=300, score=0.865, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=300, score=0.870, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=300, score=0.892, total=   0.5s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=300, score=0.858, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=300, score=0.845, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=400, score=0.858, total=   0.5s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=400, score=0.885, total=   0.5s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=400, score=0.882, total=   0.6s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=400, score=0.858, total=   0.5s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=400, score=0.848, total=   0.5s
# [CV] criterion=gini, max_depth=7, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=500, score=0.858, total=   0.7s
# [CV] criterion=gini, max_depth=7, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=500, score=0.873, total=   0.7s
# [CV] criterion=gini, max_depth=7, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=500, score=0.885, total=   0.6s
# [CV] criterion=gini, max_depth=7, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=500, score=0.870, total=   0.6s
# [CV] criterion=gini, max_depth=7, n_estimators=500 ...................
# [CV]  criterion=gini, max_depth=7, n_estimators=500, score=0.833, total=   0.6s
# [CV] criterion=gini, max_depth=11, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=100, score=0.882, total=   0.3s
# [CV] criterion=gini, max_depth=11, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=100, score=0.877, total=   0.3s
# [CV] criterion=gini, max_depth=11, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=100, score=0.877, total=   0.3s
# [CV] criterion=gini, max_depth=11, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=100, score=0.858, total=   0.3s
# [CV] criterion=gini, max_depth=11, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=100, score=0.860, total=   0.3s
# [CV] criterion=gini, max_depth=11, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=200, score=0.887, total=   0.3s
# [CV] criterion=gini, max_depth=11, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=200, score=0.882, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=200, score=0.895, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=200, score=0.875, total=   0.3s
# [CV] criterion=gini, max_depth=11, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=200, score=0.868, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=250, score=0.870, total=   0.5s
# [CV] criterion=gini, max_depth=11, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=250, score=0.892, total=   0.5s
# [CV] criterion=gini, max_depth=11, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=250, score=0.890, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=250, score=0.870, total=   0.5s
# [CV] criterion=gini, max_depth=11, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=250, score=0.860, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=300, score=0.885, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=300, score=0.880, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=300, score=0.902, total=   0.5s
# [CV] criterion=gini, max_depth=11, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=300, score=0.868, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=300, score=0.863, total=   0.4s
# [CV] criterion=gini, max_depth=11, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=400, score=0.877, total=   0.5s
# [CV] criterion=gini, max_depth=11, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=400, score=0.882, total=   0.5s
# [CV] criterion=gini, max_depth=11, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=400, score=0.890, total=   0.5s
# [CV] criterion=gini, max_depth=11, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=400, score=0.875, total=   0.6s
# [CV] criterion=gini, max_depth=11, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=400, score=0.863, total=   0.5s
# [CV] criterion=gini, max_depth=11, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=500, score=0.875, total=   0.7s
# [CV] criterion=gini, max_depth=11, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=500, score=0.882, total=   0.7s
# [CV] criterion=gini, max_depth=11, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=500, score=0.882, total=   0.7s
# [CV] criterion=gini, max_depth=11, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=500, score=0.882, total=   0.7s
# [CV] criterion=gini, max_depth=11, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=11, n_estimators=500, score=0.865, total=   0.7s
# [CV] criterion=gini, max_depth=15, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=100, score=0.870, total=   0.3s
# [CV] criterion=gini, max_depth=15, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=100, score=0.880, total=   0.3s
# [CV] criterion=gini, max_depth=15, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=100, score=0.892, total=   0.2s
# [CV] criterion=gini, max_depth=15, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=100, score=0.855, total=   0.3s
# [CV] criterion=gini, max_depth=15, n_estimators=100 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=100, score=0.850, total=   0.3s
# [CV] criterion=gini, max_depth=15, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=200, score=0.885, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=200, score=0.885, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=200, score=0.897, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=200, score=0.870, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=200 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=200, score=0.850, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=250, score=0.885, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=250, score=0.900, total=   0.5s
# [CV] criterion=gini, max_depth=15, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=250, score=0.895, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=250, score=0.880, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=250 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=250, score=0.860, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=300, score=0.880, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=300, score=0.890, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=300, score=0.892, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=300, score=0.880, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=300 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=300, score=0.865, total=   0.4s
# [CV] criterion=gini, max_depth=15, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=400, score=0.882, total=   0.5s
# [CV] criterion=gini, max_depth=15, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=400, score=0.870, total=   0.5s
# [CV] criterion=gini, max_depth=15, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=400, score=0.900, total=   0.5s
# [CV] criterion=gini, max_depth=15, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=400, score=0.880, total=   0.5s
# [CV] criterion=gini, max_depth=15, n_estimators=400 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=400, score=0.865, total=   0.5s
# [CV] criterion=gini, max_depth=15, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=500, score=0.887, total=   0.7s
# [CV] criterion=gini, max_depth=15, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=500, score=0.875, total=   0.7s
# [CV] criterion=gini, max_depth=15, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=500, score=0.890, total=   0.7s
# [CV] criterion=gini, max_depth=15, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=500, score=0.865, total=   0.7s
# [CV] criterion=gini, max_depth=15, n_estimators=500 ..................
# [CV]  criterion=gini, max_depth=15, n_estimators=500, score=0.877, total=   0.7s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=100, score=0.593, total=   0.3s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=100, score=0.540, total=   0.2s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=100, score=0.550, total=   0.2s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=100, score=0.527, total=   0.2s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=100, score=0.557, total=   0.2s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=200, score=0.585, total=   0.3s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=200, score=0.562, total=   0.3s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=200, score=0.565, total=   0.3s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=200, score=0.532, total=   0.3s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=200, score=0.560, total=   0.3s
# [CV] criterion=entropy, max_depth=1, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=250, score=0.540, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=250, score=0.562, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=250, score=0.517, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=250, score=0.550, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=250, score=0.555, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=300, score=0.545, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=300, score=0.552, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=300, score=0.550, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=300, score=0.562, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=300, score=0.547, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=400, score=0.542, total=   0.5s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=400, score=0.547, total=   0.5s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=400, score=0.545, total=   0.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=400, score=0.588, total=   0.5s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=400, score=0.540, total=   0.5s
# [CV] criterion=entropy, max_depth=1, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=500, score=0.568, total=   0.6s
# [CV] criterion=entropy, max_depth=1, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=500, score=0.565, total=   0.6s
# [CV] criterion=entropy, max_depth=1, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=500, score=0.557, total=   0.6s
# [CV] criterion=entropy, max_depth=1, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=500, score=0.573, total=   0.6s
# [CV] criterion=entropy, max_depth=1, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=1, n_estimators=500, score=0.537, total=   0.6s
# [CV] criterion=entropy, max_depth=2, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=100, score=0.708, total=   0.2s
# [CV] criterion=entropy, max_depth=2, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=100, score=0.640, total=   0.2s
# [CV] criterion=entropy, max_depth=2, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=100, score=0.603, total=   0.2s
# [CV] criterion=entropy, max_depth=2, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=100, score=0.688, total=   0.2s
# [CV] criterion=entropy, max_depth=2, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=100, score=0.657, total=   0.2s
# [CV] criterion=entropy, max_depth=2, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=200, score=0.652, total=   0.3s
# [CV] criterion=entropy, max_depth=2, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=200, score=0.682, total=   0.3s
# [CV] criterion=entropy, max_depth=2, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=200, score=0.718, total=   0.3s
# [CV] criterion=entropy, max_depth=2, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=200, score=0.672, total=   0.3s
# [CV] criterion=entropy, max_depth=2, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=200, score=0.642, total=   0.3s
# [CV] criterion=entropy, max_depth=2, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=250, score=0.660, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=250, score=0.645, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=250, score=0.657, total=   0.5s
# [CV] criterion=entropy, max_depth=2, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=250, score=0.723, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=250, score=0.630, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=300, score=0.688, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=300, score=0.662, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=300, score=0.710, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=300, score=0.715, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=300, score=0.647, total=   0.4s
# [CV] criterion=entropy, max_depth=2, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=400, score=0.667, total=   0.5s
# [CV] criterion=entropy, max_depth=2, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=400, score=0.680, total=   0.5s
# [CV] criterion=entropy, max_depth=2, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=400, score=0.690, total=   0.5s
# [CV] criterion=entropy, max_depth=2, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=400, score=0.715, total=   0.5s
# [CV] criterion=entropy, max_depth=2, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=400, score=0.672, total=   0.5s
# [CV] criterion=entropy, max_depth=2, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=500, score=0.700, total=   0.6s
# [CV] criterion=entropy, max_depth=2, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=500, score=0.652, total=   0.6s
# [CV] criterion=entropy, max_depth=2, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=500, score=0.700, total=   0.6s
# [CV] criterion=entropy, max_depth=2, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=500, score=0.710, total=   0.6s
# [CV] criterion=entropy, max_depth=2, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=2, n_estimators=500, score=0.685, total=   0.6s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=100, score=0.833, total=   0.2s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=100, score=0.818, total=   0.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=100, score=0.865, total=   0.2s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=100, score=0.830, total=   0.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=100, score=0.833, total=   0.2s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=200, score=0.838, total=   0.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=200, score=0.830, total=   0.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=200, score=0.863, total=   0.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=200, score=0.833, total=   0.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=200, score=0.825, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=250, score=0.845, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=250, score=0.848, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=250, score=0.873, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=250, score=0.840, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=250, score=0.833, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=300, score=0.840, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=300, score=0.843, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=300, score=0.865, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=300, score=0.833, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=300, score=0.840, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=400, score=0.843, total=   0.5s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=400, score=0.833, total=   0.5s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=400, score=0.860, total=   0.5s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=400, score=0.840, total=   0.5s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=400, score=0.840, total=   0.5s
# [CV] criterion=entropy, max_depth=5, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=500, score=0.850, total=   0.6s
# [CV] criterion=entropy, max_depth=5, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=500, score=0.833, total=   0.6s
# [CV] criterion=entropy, max_depth=5, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=500, score=0.868, total=   0.6s
# [CV] criterion=entropy, max_depth=5, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=500, score=0.840, total=   0.6s
# [CV] criterion=entropy, max_depth=5, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=5, n_estimators=500, score=0.840, total=   0.6s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=100, score=0.858, total=   0.2s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=100, score=0.853, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=100, score=0.897, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=100, score=0.858, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=100, score=0.845, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=200, score=0.865, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=200, score=0.858, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=200, score=0.875, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=200, score=0.858, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=200, score=0.850, total=   0.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=250, score=0.858, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=250, score=0.858, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=250, score=0.897, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=250, score=0.863, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=250 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=250, score=0.860, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=300, score=0.848, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=300, score=0.863, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=300, score=0.905, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=300, score=0.853, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=300, score=0.850, total=   0.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=400, score=0.863, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=400, score=0.863, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=400, score=0.887, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=400, score=0.855, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=400, score=0.848, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=500, score=0.868, total=   0.7s
# [CV] criterion=entropy, max_depth=7, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=500, score=0.863, total=   0.7s
# [CV] criterion=entropy, max_depth=7, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=500, score=0.895, total=   0.6s
# [CV] criterion=entropy, max_depth=7, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=500, score=0.845, total=   0.7s
# [CV] criterion=entropy, max_depth=7, n_estimators=500 ................
# [CV]  criterion=entropy, max_depth=7, n_estimators=500, score=0.855, total=   0.6s
# [CV] criterion=entropy, max_depth=11, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=100, score=0.882, total=   0.3s
# [CV] criterion=entropy, max_depth=11, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=100, score=0.887, total=   0.3s
# [CV] criterion=entropy, max_depth=11, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=100, score=0.907, total=   0.3s
# [CV] criterion=entropy, max_depth=11, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=100, score=0.870, total=   0.3s
# [CV] criterion=entropy, max_depth=11, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=100, score=0.863, total=   0.3s
# [CV] criterion=entropy, max_depth=11, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=200, score=0.882, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=200, score=0.897, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=200, score=0.912, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=200, score=0.868, total=   0.3s
# [CV] criterion=entropy, max_depth=11, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=200, score=0.882, total=   0.3s
# [CV] criterion=entropy, max_depth=11, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=250, score=0.897, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=250, score=0.887, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=250, score=0.905, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=250, score=0.873, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=250, score=0.873, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=300, score=0.880, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=300, score=0.897, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=300, score=0.907, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=300, score=0.865, total=   0.5s
# [CV] criterion=entropy, max_depth=11, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=300, score=0.873, total=   0.4s
# [CV] criterion=entropy, max_depth=11, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=400, score=0.880, total=   0.5s
# [CV] criterion=entropy, max_depth=11, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=400, score=0.892, total=   0.5s
# [CV] criterion=entropy, max_depth=11, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=400, score=0.900, total=   0.5s
# [CV] criterion=entropy, max_depth=11, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=400, score=0.865, total=   0.5s
# [CV] criterion=entropy, max_depth=11, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=400, score=0.863, total=   0.5s
# [CV] criterion=entropy, max_depth=11, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=500, score=0.875, total=   0.7s
# [CV] criterion=entropy, max_depth=11, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=500, score=0.885, total=   0.7s
# [CV] criterion=entropy, max_depth=11, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=500, score=0.915, total=   0.7s
# [CV] criterion=entropy, max_depth=11, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=500, score=0.873, total=   0.7s
# [CV] criterion=entropy, max_depth=11, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=11, n_estimators=500, score=0.873, total=   0.7s
# [CV] criterion=entropy, max_depth=15, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=100, score=0.880, total=   0.3s
# [CV] criterion=entropy, max_depth=15, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=100, score=0.880, total=   0.3s
# [CV] criterion=entropy, max_depth=15, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=100, score=0.895, total=   0.3s
# [CV] criterion=entropy, max_depth=15, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=100, score=0.868, total=   0.3s
# [CV] criterion=entropy, max_depth=15, n_estimators=100 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=100, score=0.875, total=   0.3s
# [CV] criterion=entropy, max_depth=15, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=200, score=0.882, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=200, score=0.890, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=200, score=0.897, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=200, score=0.875, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=200 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=200, score=0.865, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=250, score=0.885, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=250, score=0.875, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=250, score=0.900, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=250, score=0.865, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=250 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=250, score=0.865, total=   0.5s
# [CV] criterion=entropy, max_depth=15, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=300, score=0.885, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=300, score=0.873, total=   0.5s
# [CV] criterion=entropy, max_depth=15, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=300, score=0.902, total=   0.5s
# [CV] criterion=entropy, max_depth=15, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=300, score=0.860, total=   0.4s
# [CV] criterion=entropy, max_depth=15, n_estimators=300 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=300, score=0.877, total=   0.5s
# [CV] criterion=entropy, max_depth=15, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=400, score=0.892, total=   0.6s
# [CV] criterion=entropy, max_depth=15, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=400, score=0.880, total=   0.6s
# [CV] criterion=entropy, max_depth=15, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=400, score=0.915, total=   0.5s
# [CV] criterion=entropy, max_depth=15, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=400, score=0.868, total=   0.6s
# [CV] criterion=entropy, max_depth=15, n_estimators=400 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=400, score=0.868, total=   0.5s
# [CV] criterion=entropy, max_depth=15, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=500, score=0.885, total=   0.7s
# [CV] criterion=entropy, max_depth=15, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=500, score=0.895, total=   0.8s
# [CV] criterion=entropy, max_depth=15, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=500, score=0.902, total=   0.7s
# [CV] criterion=entropy, max_depth=15, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=500, score=0.873, total=   0.7s
# [CV] criterion=entropy, max_depth=15, n_estimators=500 ...............
# [CV]  criterion=entropy, max_depth=15, n_estimators=500, score=0.870, total=   0.7s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed:  2.7min finished
# Best score: 0.8885

# %%
print("Best parameters set:")
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Best parameters set:
# 	criterion: entropy
# 	max_depth: 11
# 	n_estimators: 200

# %%
model
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=-1), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 5, 7, 11, 15],
#                          'n_estimators': [100, 200, 250, 300, 400, 500]},
#              scoring='accuracy', verbose=10)

# %%
# define the model here
# i am using random forest with n_jobs=-1
# n_jobs=-1 => use all cores
classifier = ensemble.RandomForestClassifier(n_jobs=-1)

# define a grid of parameters
# this can be a dictionary or a list of
# dictionaries
param_grid = {
    "n_estimators": np.arange(100, 1500, 100), "max_depth": np.arange(1, 31), "criterion": ["gini", "entropy"]
}

# initialize random search
# estimator is the model that we have defined
# param_distributions is the grid/distribution of parameters
# we use accuracy as our metric. you can define your own
# higher value of verbose implies a lot of details are printed
# cv=5 means that we are using 5 fold cv (not stratified)
# n_iter is the number of iterations we want
# if param_distributions has all the values as list,
# random search will be done by sampling without replacement
# if any of the parameters come from a distribution,
# random search uses sampling with replacement
model = model_selection.RandomizedSearchCV(
    estimator=classifier, param_distributions=param_grid, n_iter=20,
    scoring="accuracy",
    verbose=10, n_jobs=1, cv=5
)

# fit the model and extract best score
model.fit(X, y)
print(f"Best score: {model.best_score_}")
print("Best parameters set:")
best_parameters = model.best_estimator_.get_params() 
for param_name in sorted(param_grid.keys()):
    print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] n_estimators=200, max_depth=4, criterion=gini ...................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=200, max_depth=4, criterion=gini, score=0.802, total=   2.2s
# [CV] n_estimators=200, max_depth=4, criterion=gini ...................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [CV]  n_estimators=200, max_depth=4, criterion=gini, score=0.812, total=   0.4s
# [CV] n_estimators=200, max_depth=4, criterion=gini ...................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.6s remaining:    0.0s
# [CV]  n_estimators=200, max_depth=4, criterion=gini, score=0.838, total=   0.4s
# [CV] n_estimators=200, max_depth=4, criterion=gini ...................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.0s remaining:    0.0s
# [CV]  n_estimators=200, max_depth=4, criterion=gini, score=0.818, total=   0.4s
# [CV] n_estimators=200, max_depth=4, criterion=gini ...................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.4s remaining:    0.0s
# [CV]  n_estimators=200, max_depth=4, criterion=gini, score=0.800, total=   0.4s
# [CV] n_estimators=1300, max_depth=29, criterion=entropy ..............
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.8s remaining:    0.0s
# [CV]  n_estimators=1300, max_depth=29, criterion=entropy, score=0.880, total=   1.8s
# [CV] n_estimators=1300, max_depth=29, criterion=entropy ..............
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.6s remaining:    0.0s
# [CV]  n_estimators=1300, max_depth=29, criterion=entropy, score=0.892, total=   1.8s
# [CV] n_estimators=1300, max_depth=29, criterion=entropy ..............
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    7.4s remaining:    0.0s
# [CV]  n_estimators=1300, max_depth=29, criterion=entropy, score=0.905, total=   1.7s
# [CV] n_estimators=1300, max_depth=29, criterion=entropy ..............
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    9.1s remaining:    0.0s
# [CV]  n_estimators=1300, max_depth=29, criterion=entropy, score=0.870, total=   1.8s
# [CV] n_estimators=1300, max_depth=29, criterion=entropy ..............
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   10.9s remaining:    0.0s
# [CV]  n_estimators=1300, max_depth=29, criterion=entropy, score=0.868, total=   1.8s
# [CV] n_estimators=100, max_depth=6, criterion=gini ...................
# [CV]  n_estimators=100, max_depth=6, criterion=gini, score=0.845, total=   0.3s
# [CV] n_estimators=100, max_depth=6, criterion=gini ...................
# [CV]  n_estimators=100, max_depth=6, criterion=gini, score=0.855, total=   0.3s
# [CV] n_estimators=100, max_depth=6, criterion=gini ...................
# [CV]  n_estimators=100, max_depth=6, criterion=gini, score=0.858, total=   0.3s
# [CV] n_estimators=100, max_depth=6, criterion=gini ...................
# [CV]  n_estimators=100, max_depth=6, criterion=gini, score=0.843, total=   0.3s
# [CV] n_estimators=100, max_depth=6, criterion=gini ...................
# [CV]  n_estimators=100, max_depth=6, criterion=gini, score=0.840, total=   0.3s
# [CV] n_estimators=500, max_depth=8, criterion=gini ...................
# [CV]  n_estimators=500, max_depth=8, criterion=gini, score=0.870, total=   0.8s
# [CV] n_estimators=500, max_depth=8, criterion=gini ...................
# [CV]  n_estimators=500, max_depth=8, criterion=gini, score=0.870, total=   0.8s
# [CV] n_estimators=500, max_depth=8, criterion=gini ...................
# [CV]  n_estimators=500, max_depth=8, criterion=gini, score=0.890, total=   0.8s
# [CV] n_estimators=500, max_depth=8, criterion=gini ...................
# [CV]  n_estimators=500, max_depth=8, criterion=gini, score=0.873, total=   0.7s
# [CV] n_estimators=500, max_depth=8, criterion=gini ...................
# [CV]  n_estimators=500, max_depth=8, criterion=gini, score=0.863, total=   0.7s
# [CV] n_estimators=600, max_depth=12, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=12, criterion=gini, score=0.882, total=   0.7s
# [CV] n_estimators=600, max_depth=12, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=12, criterion=gini, score=0.885, total=   0.7s
# [CV] n_estimators=600, max_depth=12, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=12, criterion=gini, score=0.890, total=   0.7s
# [CV] n_estimators=600, max_depth=12, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=12, criterion=gini, score=0.875, total=   0.7s
# [CV] n_estimators=600, max_depth=12, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=12, criterion=gini, score=0.860, total=   0.7s
# [CV] n_estimators=900, max_depth=2, criterion=entropy ................
# [CV]  n_estimators=900, max_depth=2, criterion=entropy, score=0.690, total=   0.9s
# [CV] n_estimators=900, max_depth=2, criterion=entropy ................
# [CV]  n_estimators=900, max_depth=2, criterion=entropy, score=0.672, total=   1.0s
# [CV] n_estimators=900, max_depth=2, criterion=entropy ................
# [CV]  n_estimators=900, max_depth=2, criterion=entropy, score=0.690, total=   1.0s
# [CV] n_estimators=900, max_depth=2, criterion=entropy ................
# [CV]  n_estimators=900, max_depth=2, criterion=entropy, score=0.703, total=   0.9s
# [CV] n_estimators=900, max_depth=2, criterion=entropy ................
# [CV]  n_estimators=900, max_depth=2, criterion=entropy, score=0.693, total=   0.8s
# [CV] n_estimators=300, max_depth=3, criterion=gini ...................
# [CV]  n_estimators=300, max_depth=3, criterion=gini, score=0.795, total=   0.4s
# [CV] n_estimators=300, max_depth=3, criterion=gini ...................
# [CV]  n_estimators=300, max_depth=3, criterion=gini, score=0.820, total=   0.4s
# [CV] n_estimators=300, max_depth=3, criterion=gini ...................
# [CV]  n_estimators=300, max_depth=3, criterion=gini, score=0.830, total=   0.4s
# [CV] n_estimators=300, max_depth=3, criterion=gini ...................
# [CV]  n_estimators=300, max_depth=3, criterion=gini, score=0.820, total=   0.4s
# [CV] n_estimators=300, max_depth=3, criterion=gini ...................
# [CV]  n_estimators=300, max_depth=3, criterion=gini, score=0.805, total=   0.4s
# [CV] n_estimators=700, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=19, criterion=gini, score=0.890, total=   0.9s
# [CV] n_estimators=700, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=19, criterion=gini, score=0.890, total=   0.9s
# [CV] n_estimators=700, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=19, criterion=gini, score=0.897, total=   0.9s
# [CV] n_estimators=700, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=19, criterion=gini, score=0.875, total=   0.9s
# [CV] n_estimators=700, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=19, criterion=gini, score=0.870, total=   0.9s
# [CV] n_estimators=600, max_depth=26, criterion=entropy ...............
# [CV]  n_estimators=600, max_depth=26, criterion=entropy, score=0.885, total=   0.8s
# [CV] n_estimators=600, max_depth=26, criterion=entropy ...............
# [CV]  n_estimators=600, max_depth=26, criterion=entropy, score=0.895, total=   0.7s
# [CV] n_estimators=600, max_depth=26, criterion=entropy ...............
# [CV]  n_estimators=600, max_depth=26, criterion=entropy, score=0.900, total=   0.7s
# [CV] n_estimators=600, max_depth=26, criterion=entropy ...............
# [CV]  n_estimators=600, max_depth=26, criterion=entropy, score=0.877, total=   0.7s
# [CV] n_estimators=600, max_depth=26, criterion=entropy ...............
# [CV]  n_estimators=600, max_depth=26, criterion=entropy, score=0.870, total=   0.7s
# [CV] n_estimators=100, max_depth=13, criterion=entropy ...............
# [CV]  n_estimators=100, max_depth=13, criterion=entropy, score=0.875, total=   0.3s
# [CV] n_estimators=100, max_depth=13, criterion=entropy ...............
# [CV]  n_estimators=100, max_depth=13, criterion=entropy, score=0.877, total=   0.3s
# [CV] n_estimators=100, max_depth=13, criterion=entropy ...............
# [CV]  n_estimators=100, max_depth=13, criterion=entropy, score=0.905, total=   0.2s
# [CV] n_estimators=100, max_depth=13, criterion=entropy ...............
# [CV]  n_estimators=100, max_depth=13, criterion=entropy, score=0.863, total=   0.3s
# [CV] n_estimators=100, max_depth=13, criterion=entropy ...............
# [CV]  n_estimators=100, max_depth=13, criterion=entropy, score=0.882, total=   0.3s
# [CV] n_estimators=1300, max_depth=9, criterion=gini ..................
# [CV]  n_estimators=1300, max_depth=9, criterion=gini, score=0.875, total=   1.6s
# [CV] n_estimators=1300, max_depth=9, criterion=gini ..................
# [CV]  n_estimators=1300, max_depth=9, criterion=gini, score=0.880, total=   1.4s
# [CV] n_estimators=1300, max_depth=9, criterion=gini ..................
# [CV]  n_estimators=1300, max_depth=9, criterion=gini, score=0.890, total=   1.3s
# [CV] n_estimators=1300, max_depth=9, criterion=gini ..................
# [CV]  n_estimators=1300, max_depth=9, criterion=gini, score=0.875, total=   1.4s
# [CV] n_estimators=1300, max_depth=9, criterion=gini ..................
# [CV]  n_estimators=1300, max_depth=9, criterion=gini, score=0.860, total=   1.4s
# [CV] n_estimators=900, max_depth=17, criterion=entropy ...............
# [CV]  n_estimators=900, max_depth=17, criterion=entropy, score=0.880, total=   1.1s
# [CV] n_estimators=900, max_depth=17, criterion=entropy ...............
# [CV]  n_estimators=900, max_depth=17, criterion=entropy, score=0.895, total=   1.1s
# [CV] n_estimators=900, max_depth=17, criterion=entropy ...............
# [CV]  n_estimators=900, max_depth=17, criterion=entropy, score=0.900, total=   1.1s
# [CV] n_estimators=900, max_depth=17, criterion=entropy ...............
# [CV]  n_estimators=900, max_depth=17, criterion=entropy, score=0.868, total=   1.1s
# [CV] n_estimators=900, max_depth=17, criterion=entropy ...............
# [CV]  n_estimators=900, max_depth=17, criterion=entropy, score=0.880, total=   1.1s
# [CV] n_estimators=100, max_depth=28, criterion=gini ..................
# [CV]  n_estimators=100, max_depth=28, criterion=gini, score=0.880, total=   0.3s
# [CV] n_estimators=100, max_depth=28, criterion=gini ..................
# [CV]  n_estimators=100, max_depth=28, criterion=gini, score=0.880, total=   0.3s
# [CV] n_estimators=100, max_depth=28, criterion=gini ..................
# [CV]  n_estimators=100, max_depth=28, criterion=gini, score=0.895, total=   0.3s
# [CV] n_estimators=100, max_depth=28, criterion=gini ..................
# [CV]  n_estimators=100, max_depth=28, criterion=gini, score=0.865, total=   0.3s
# [CV] n_estimators=100, max_depth=28, criterion=gini ..................
# [CV]  n_estimators=100, max_depth=28, criterion=gini, score=0.865, total=   0.3s
# [CV] n_estimators=1400, max_depth=11, criterion=gini .................
# [CV]  n_estimators=1400, max_depth=11, criterion=gini, score=0.880, total=   1.4s
# [CV] n_estimators=1400, max_depth=11, criterion=gini .................
# [CV]  n_estimators=1400, max_depth=11, criterion=gini, score=0.885, total=   1.4s
# [CV] n_estimators=1400, max_depth=11, criterion=gini .................
# [CV]  n_estimators=1400, max_depth=11, criterion=gini, score=0.900, total=   1.4s
# [CV] n_estimators=1400, max_depth=11, criterion=gini .................
# [CV]  n_estimators=1400, max_depth=11, criterion=gini, score=0.875, total=   1.4s
# [CV] n_estimators=1400, max_depth=11, criterion=gini .................
# [CV]  n_estimators=1400, max_depth=11, criterion=gini, score=0.863, total=   1.4s
# [CV] n_estimators=700, max_depth=20, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=20, criterion=gini, score=0.890, total=   0.9s
# [CV] n_estimators=700, max_depth=20, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=20, criterion=gini, score=0.890, total=   0.8s
# [CV] n_estimators=700, max_depth=20, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=20, criterion=gini, score=0.895, total=   0.9s
# [CV] n_estimators=700, max_depth=20, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=20, criterion=gini, score=0.885, total=   0.9s
# [CV] n_estimators=700, max_depth=20, criterion=gini ..................
# [CV]  n_estimators=700, max_depth=20, criterion=gini, score=0.870, total=   0.8s
# [CV] n_estimators=700, max_depth=20, criterion=entropy ...............
# [CV]  n_estimators=700, max_depth=20, criterion=entropy, score=0.885, total=   0.9s
# [CV] n_estimators=700, max_depth=20, criterion=entropy ...............
# [CV]  n_estimators=700, max_depth=20, criterion=entropy, score=0.895, total=   0.9s
# [CV] n_estimators=700, max_depth=20, criterion=entropy ...............
# [CV]  n_estimators=700, max_depth=20, criterion=entropy, score=0.900, total=   0.9s
# [CV] n_estimators=700, max_depth=20, criterion=entropy ...............
# [CV]  n_estimators=700, max_depth=20, criterion=entropy, score=0.882, total=   0.9s
# [CV] n_estimators=700, max_depth=20, criterion=entropy ...............
# [CV]  n_estimators=700, max_depth=20, criterion=entropy, score=0.868, total=   0.9s
# [CV] n_estimators=200, max_depth=26, criterion=gini ..................
# [CV]  n_estimators=200, max_depth=26, criterion=gini, score=0.895, total=   0.4s
# [CV] n_estimators=200, max_depth=26, criterion=gini ..................
# [CV]  n_estimators=200, max_depth=26, criterion=gini, score=0.885, total=   0.4s
# [CV] n_estimators=200, max_depth=26, criterion=gini ..................
# [CV]  n_estimators=200, max_depth=26, criterion=gini, score=0.887, total=   0.4s
# [CV] n_estimators=200, max_depth=26, criterion=gini ..................
# [CV]  n_estimators=200, max_depth=26, criterion=gini, score=0.873, total=   0.4s
# [CV] n_estimators=200, max_depth=26, criterion=gini ..................
# [CV]  n_estimators=200, max_depth=26, criterion=gini, score=0.863, total=   0.4s
# [CV] n_estimators=1200, max_depth=18, criterion=gini .................
# [CV]  n_estimators=1200, max_depth=18, criterion=gini, score=0.877, total=   1.3s
# [CV] n_estimators=1200, max_depth=18, criterion=gini .................
# [CV]  n_estimators=1200, max_depth=18, criterion=gini, score=0.880, total=   1.6s
# [CV] n_estimators=1200, max_depth=18, criterion=gini .................
# [CV]  n_estimators=1200, max_depth=18, criterion=gini, score=0.900, total=   1.3s
# [CV] n_estimators=1200, max_depth=18, criterion=gini .................
# [CV]  n_estimators=1200, max_depth=18, criterion=gini, score=0.873, total=   1.3s
# [CV] n_estimators=1200, max_depth=18, criterion=gini .................
# [CV]  n_estimators=1200, max_depth=18, criterion=gini, score=0.860, total=   1.3s
# [CV] n_estimators=500, max_depth=27, criterion=gini ..................
# [CV]  n_estimators=500, max_depth=27, criterion=gini, score=0.882, total=   0.7s
# [CV] n_estimators=500, max_depth=27, criterion=gini ..................
# [CV]  n_estimators=500, max_depth=27, criterion=gini, score=0.887, total=   0.7s
# [CV] n_estimators=500, max_depth=27, criterion=gini ..................
# [CV]  n_estimators=500, max_depth=27, criterion=gini, score=0.892, total=   0.7s
# [CV] n_estimators=500, max_depth=27, criterion=gini ..................
# [CV]  n_estimators=500, max_depth=27, criterion=gini, score=0.875, total=   0.7s
# [CV] n_estimators=500, max_depth=27, criterion=gini ..................
# [CV]  n_estimators=500, max_depth=27, criterion=gini, score=0.875, total=   0.7s
# [CV] n_estimators=600, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=19, criterion=gini, score=0.885, total=   0.7s
# [CV] n_estimators=600, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=19, criterion=gini, score=0.890, total=   0.7s
# [CV] n_estimators=600, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=19, criterion=gini, score=0.895, total=   0.7s
# [CV] n_estimators=600, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=19, criterion=gini, score=0.882, total=   0.7s
# [CV] n_estimators=600, max_depth=19, criterion=gini ..................
# [CV]  n_estimators=600, max_depth=19, criterion=gini, score=0.868, total=   0.7s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  1.4min finished
# Best score: 0.8859999999999999
# Best parameters set:
# 	criterion: gini
# 	max_depth: 20
# 	n_estimators: 700
